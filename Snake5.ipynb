# %%
import numpy as np
import random
from copy import deepcopy

# %%
class SnakeNode():
    def __init__(self, parent, x, y):
        self.parent = parent
        self.x = x
        self.y = y
    def SetX(self, newx):
        self.x = newx
    def SetY(self, newy):
        self.y = newy
    def SetParent(self, newparent):
        self.parent = newparent
    def Pos(self):
        return (self.x, self.y)
    def Index(self):
        return (self.y, self.x)

# %%
class Snake():

    def __init__(self, HeadX, HeadY):
        self.head = SnakeNode(None, HeadX, HeadY)
        self.tail = self.head

    def MoveBodyForward(self):
        currentnode = self.tail
        while (currentnode.parent != None):
            parentpos = currentnode.parent.Pos()
            currentnode.SetX(parentpos[0])
            currentnode.SetY(parentpos[1])
            currentnode = currentnode.parent

    def Move(self, direction):
        (oldtailx, oldtaily) = self.tail.Pos()
        self.MoveBodyForward()
        headpos = self.head.Pos()
        if direction == 0:
            self.head.SetY(headpos[1] - 1)
        elif direction == 1:
            self.head.SetX(headpos[0] + 1)
        elif direction == 2:
            self.head.SetY(headpos[1] + 1)
        elif direction == 3:
            self.head.SetX(headpos[0] - 1)
        
        return (oldtailx, oldtaily, *self.head.Pos())
    
    def NewHead(self, headx, heady):
        newhead = SnakeNode(None, headx, heady)
        self.head.SetParent(newhead)
        self.head = newhead

    def Head(self):
        return self.head
    def Tail(self):
        return self.tail

# %%
class Game():
    x = 1
    def __init__(self, weights):
        self.foodval = 10
        self.headval = 5
        self.bodyval = 2
        self.features = np.zeros(5, dtype= int)
        #self.theta = np.ones(np.shape(self.features), dtype= int)
        self.theta = weights
        self.statevalue = 0
        self.obstacleval = 1
        self.length = 1
        self.board = np.zeros((20,20), dtype=int)
        self.SpawnObstacle()
        self.SpawnSnake()
        self.SpawnFood()




    def SpawnObstacle(self):
        obstaclespawns = []
        obstaclespawns.append(np.random.randint(1, 19, size=(2)))
        obstaclespawns.append(np.random.randint(1, 19, size=(2)))
        obstaclespawns.append(np.random.randint(1, 19, size=(2)))
        obstaclespawns.append(np.random.randint(1, 19, size=(2)))
        for i in obstaclespawns:
            b0 = i
            b1 = (i[0] + 1, i[1])
            b2 = (i[0], i[1] + 1)
            b3 = (i[0] + 1, i[1] + 1)
            self.board[b0[0], b0[1]] = self.obstacleval
            self.board[b1[0], b1[1]] = self.obstacleval
            self.board[b2[0], b2[1]] = self.obstacleval
            self.board[b3[0], b3[1]] = self.obstacleval



    def SpawnSnake(self):
        snakespawns = []
        for index, cell in np.ndenumerate(self.board):
            if cell == 0:
                snakespawns.append(index)
        self.snakespawn = random.choice(snakespawns)
        startx = self.snakespawn[0]
        starty = self.snakespawn[1]
        #self.board[startx, starty] = self.headval
        self.snake = Snake(startx, starty)
        return startx, starty


    def SpawnFood(self):
        foodspawns = []
        for index, cell in np.ndenumerate(self.board):
            if cell == 0:
                foodspawns.append(index)
        self.foodspawn = random.choice(foodspawns)
        self.board[self.foodspawn] = self.foodval

    def HeadPos(self, direction, headx, heady):
        if(0<headx<20) and (0<heady<20):
            if direction == 0:
                heady -= 1
            elif direction == 1:
                headx += 1
            elif direction == 2:
                heady += 1
            elif direction == 3:
                headx -= 1
        return (headx, heady)
    
    def CollisionCheck(self, direction, headx, heady):
        
        headx, heady = self.HeadPos(direction, headx, heady)

        if (headx == 0) or (headx == 20) or (heady == 0) or (heady == 20):
            return True
        elif self.board[heady, headx] == self.bodyval:
            return True
        elif self.board[heady, headx] == self.obstacleval:
            return True
        return False
   
    def Extractfeatures(self, headx, heady):
        
        for i in range(4):
            self.features[i] = self.CollisionCheck(i, headx, heady)
        #dist = self.FoodDirection(heady, headx)
        #self.features[4:] = 1 / (dist + 1)
        self.features[4:] = deepcopy(self.FoodDirection(heady, headx))
        return self.features
    
    def FoodDirection(self, heady, headx):
        foodvector = np.array(self.foodspawn) - np.array((heady, headx))
        foodfeatures = np.abs(foodvector)
        mandist = foodfeatures[0] + foodfeatures[1]
        return mandist

    def Move(self, direction):
        (headx, heady) = self.snake.Head().Pos()
        gameisover = False
        if not self.CollisionCheck(direction, headx, heady):
            reward = 0
            (headx, heady) = self.snake.Head().Pos()
            self.board[heady, headx] = self.bodyval


            potx, poty = self.HeadPos(direction, headx, heady)

            if self.board[poty, potx] == self.foodval:
                self.snake.NewHead(potx, poty)
                self.board[poty, potx] = self.headval
                self.SpawnFood()
                self.length += 1 
                reward = 10000
            else:
                (oldtailx, oldtaily, newheadx, newheady) = self.snake.Move(direction)
                self.board[oldtaily, oldtailx] = 0
                self.board[newheady, newheadx] = self.headval
        else:
            reward = -1000
            gameisover = True
        
        self.features = self.Extractfeatures(headx, heady)
        self.statevalue = np.dot(self.theta.T, self.features)
        return self.statevalue, self.features, reward, gameisover, self.length


    def BestMove(self):
        (headx, heady) = self.snake.Head().Pos()
        Wfeatures = deepcopy(self.Extractfeatures(headx, heady-1))
        Afeatures = deepcopy(self.Extractfeatures(headx-1, heady))
        Sfeatures = deepcopy(self.Extractfeatures(headx, heady+1))
        Dfeatures = deepcopy(self.Extractfeatures(headx+1, heady))
        Wscore = np.dot(self.theta.T, Wfeatures)
        Ascore = np.dot(self.theta.T, Afeatures)
        Sscore = np.dot(self.theta.T, Sfeatures)
        Dscore = np.dot(self.theta.T, Dfeatures)
        scores = []
        scores.append(Wscore)
        scores.append(Dscore)
        scores.append(Sscore)
        scores.append(Ascore)
        bestmove = np.argmax(scores)
        return bestmove


    def display(self):
        for i in range(22):
            print('-', end='')

        for i in range(20):
            print('\n|', end='')
            for j in range(20):
                if self.board[i, j] == 0:
                    print(' ', end='')
                elif self.board[i, j] == self.headval:
                    print('S', end='')
                elif self.board[i, j] == self.bodyval:
                    print('#', end='')
                elif self.board[i, j] == self.foodval:
                    print('F', end='')
                elif self.board[i, j] == self.obstacleval:
                    print('X', end='')
            print('|', end='')
        print()
        for i in range(22):
            print('-', end='')
        print()

# %%
def Epoch(weights):
    gamelog = []
    rewardlog = []
    valuelog = []
    game = Game(weights)

    while True:
        game.display()
        direction = game.BestMove()
        #direction = input("Input Direction (w,a,s,d or q to quit): ")
        if direction == 0:
            statevalue, features, reward, gameOver, score = game.Move(0)
        elif direction == 3:
            statevalue, features, reward, gameOver, score = game.Move(3)
        elif direction == 2:
            statevalue, features, reward, gameOver, score = game.Move(2)
        elif direction == 1:
            statevalue, features, reward, gameOver, score = game.Move(1)


        tempval = deepcopy(statevalue)
        tempfeature = deepcopy(features)
        tempreward = deepcopy(reward)
        rewardlog.append(tempreward)
        gamelog.append(tempfeature)
        valuelog.append(tempval)
        print(f"features:{features}  statevalue:{statevalue}  reward:{reward}, length: {score}")

        if gameOver:
            print(f"Game Over, Snake Length:{score}")
            break
    
    return gamelog, rewardlog, score

# %%
def UpdateWeigths(weights, gamelog, rewardlog, learning_rate):
    lastfeature = deepcopy(gamelog[-1])
    realreward = deepcopy(rewardlog[-1])
    rewardhat = np.dot(weights.T, lastfeature)
    weights = weights + learning_rate*(realreward - 0)*lastfeature
    return weights

# %%
weights = np.array([0, 0, 0, 0, 0])
learning_rate = 0.0001
iterations = 30
longest_snake = 0
for i in range(iterations):
    gamelog, rewardlog , score= Epoch(weights)
    weights = UpdateWeigths(weights, gamelog, rewardlog, learning_rate)
    if score > longest_snake:
        longest_snake = score
# Out:
# Streaming output truncated to the last 5000 lines.
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F              XX   |
# |                    |
# |         S          |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 11]  statevalue:-216.70000000000005  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F              XX   |
# |         S          |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 10]  statevalue:-197.00000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F        S     XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 9]  statevalue:-177.3  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F       S      XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 8]  statevalue:-157.60000000000002  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F      S       XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-137.90000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F     S        XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-118.20000000000002  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F    S         XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-98.50000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F   S          XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-78.80000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F  S           XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-59.10000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |F S            XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-39.400000000000006  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |        XXXX        |
# |        XXXX        |
# |                    |
# |               XX   |
# |FS             XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[0 0 0 1 1]  statevalue:-20.500000000000004  reward:-1000, length: 1
# Game Over, Snake Length:1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |         F          |
# |       XX           |
# |       XX           |
# |         XX  XX     |
# |         XX  XX     |
# |                    |
# |                    |
# |                    |
# |                    |
# |              XX    |
# |              XX    |
# |                    |
# ----------------------
# features:[ 1  1  1  1 13]  statevalue:-260.90000000000003  reward:-1000, length: 1
# Game Over, Snake Length:1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F                   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 8]  statevalue:-168.80000000000004  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F                   |
# |      S             |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-147.70000000000005  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F     S             |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-126.60000000000002  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F    S              |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-105.50000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F   S               |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-84.40000000000002  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F  S                |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-63.30000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |F S                 |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-42.20000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |FS                  |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |             XX     |
# |             XX     |
# ----------------------
# features:[0 0 0 1 1]  statevalue:-22.100000000000005  reward:-1000, length: 1
# Game Over, Snake Length:1
# ----------------------
# |                    |
# |           XX       |
# |           XX       |
# |                    |
# |                    |
# |                    |
# |                    |
# |   XX               |
# |   XX F             |
# | XX                 |
# | XX                 |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |     XX             |
# |     XX             |
# ----------------------
# features:[ 1  1  1  1 11]  statevalue:-237.20000000000007  reward:-1000, length: 1
# Game Over, Snake Length:1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      F       |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-156.10000000000005  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      F       |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX       S      |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-133.80000000000004  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      F       |
# |    XX              |
# |                    |
# |                    |
# |             S      |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-111.50000000000004  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      F       |
# |    XX              |
# |                    |
# |             S      |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-89.20000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      F       |
# |    XX              |
# |             S      |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-66.90000000000002  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      F       |
# |    XX       S      |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-44.600000000000016  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX      FS      |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 11]  statevalue:-245.3000000000001  reward:10000, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F                |
# |    XX      S#      |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 10]  statevalue:-223.00000000000009  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F        S       |
# |    XX      #       |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 9]  statevalue:-200.70000000000007  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F       S#       |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 8]  statevalue:-178.40000000000006  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F      S#        |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-156.10000000000005  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F     S#         |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-133.80000000000004  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F    S#          |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-111.50000000000004  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F   S#           |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-89.20000000000003  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F  S#            |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-66.90000000000002  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   F S#             |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 1 0 2]  statevalue:-45.500000000000014  reward:0, length: 2
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   FS#              |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 1 1 0 9]  statevalue:-202.50000000000009  reward:10000, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   S##              |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  1  0  0 10]  statevalue:-223.9000000000001  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   ##               |
# |   SXX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[1 1 0 0 9]  statevalue:-203.00000000000009  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |   #                |
# |   #XX              |
# |   SXX              |
# |                    |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[1 1 0 0 8]  statevalue:-180.70000000000007  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |   #XX              |
# |   #XX              |
# |   S                |
# |                    |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[1 0 0 0 7]  statevalue:-157.50000000000006  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX              |
# |   #XX              |
# |   #                |
# |   S                |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[1 0 0 0 6]  statevalue:-135.20000000000005  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX              |
# |    XX              |
# |   #                |
# |   #S               |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 1 5]  statevalue:-112.70000000000005  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX              |
# |    XX              |
# |                    |
# |   ##S              |
# |                    |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 1 4]  statevalue:-90.40000000000003  reward:0, length: 3
# ----------------------
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# | XX                 |
# | XX                 |
# |                    |
# |    XX              |
# |    XX              |
# |                    |
# |    ##              |
# |     S              |
# |    XX              |
# |    XX           XX |
# |     F           XX |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[1 0 1 0 3]  statevalue:-69.20000000000002  reward:-1000, length: 3
# Game Over, Snake Length:3
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |               F    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 1 0 0 5]  statevalue:-113.90000000000005  reward:0, length: 1
# ----------------------
# |                    |
# |      XX            |
# |      XX          S |
# |               F    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-90.40000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |               F  S |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-67.80000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |               F S  |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-45.20000000000002  reward:0, length: 1
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |               FS   |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 15]  statevalue:-339.0000000000001  reward:10000, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |               S#   |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 14]  statevalue:-316.4000000000001  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |               #    |
# |     XX        S    |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 13]  statevalue:-293.8000000000001  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX        #    |
# |     XX        S    |
# |                    |
# |               XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 12]  statevalue:-271.2000000000001  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX       S#    |
# |                    |
# |               XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 11]  statevalue:-248.60000000000008  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX       #     |
# |              S     |
# |               XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 10]  statevalue:-226.00000000000009  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |             S#     |
# |               XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 9]  statevalue:-203.4000000000001  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |             #      |
# |             S XX   |
# |               XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 8]  statevalue:-180.80000000000007  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |             # XX   |
# |             S XX   |
# |       F            |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-158.20000000000005  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |             # XX   |
# |       F     S      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-135.60000000000005  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       F    S#      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-113.00000000000004  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       F   S#       |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-90.40000000000003  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       F  S#        |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-67.80000000000003  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       F S#         |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-45.20000000000002  reward:0, length: 2
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       FS#          |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 1 0 0 5]  statevalue:-113.90000000000005  reward:10000, length: 3
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       S##          |
# |                    |
# |                    |
# |      F             |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 1 0 0 4]  statevalue:-91.30000000000004  reward:0, length: 3
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       ##           |
# |       S            |
# |                    |
# |      F             |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[1 0 0 0 3]  statevalue:-69.30000000000003  reward:0, length: 3
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |       #            |
# |       #            |
# |       S            |
# |      F             |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[1 0 0 0 2]  statevalue:-46.70000000000002  reward:0, length: 3
# ----------------------
# |                    |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |       #            |
# |       #            |
# |      FS            |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 1  0  0  0 16]  statevalue:-363.10000000000014  reward:10000, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |       #            |
# |       #            |
# |      S#            |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  1  0  0 15]  statevalue:-339.9000000000001  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |       #            |
# |     S##            |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  1  0  0 14]  statevalue:-317.30000000000007  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |     S              |
# |     ###            |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  1  0 13]  statevalue:-294.8000000000001  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |     S              |
# |     #              |
# |     ##             |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  1  0 12]  statevalue:-272.2000000000001  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |               XX   |
# |     S              |
# |     #              |
# |     #              |
# |     #              |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  1  0 11]  statevalue:-249.60000000000008  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |               XX   |
# |     S         XX   |
# |     #              |
# |     #              |
# |     #              |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  1  0 10]  statevalue:-227.00000000000009  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |     S         XX   |
# |     #         XX   |
# |     #              |
# |     #              |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 1 0 9]  statevalue:-204.4000000000001  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |                    |
# |    S#         XX   |
# |     #         XX   |
# |     #              |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 1 0 0 8]  statevalue:-181.70000000000007  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |    S               |
# |    ##         XX   |
# |     #         XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 1 0 7]  statevalue:-159.20000000000005  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |     XX             |
# |   S#               |
# |    ##         XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 1 0 0 6]  statevalue:-136.50000000000006  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |     XX             |
# |   S XX             |
# |   ##               |
# |    #          XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 1 0 5]  statevalue:-114.00000000000004  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |                    |
# |   S XX             |
# |   # XX             |
# |   ##               |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 1 0 4]  statevalue:-91.40000000000003  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |      XX            |
# |   S                |
# |   # XX             |
# |   # XX             |
# |   #                |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ----------------------
# features:[0 0 1 0 3]  statevalue:-68.80000000000003  reward:0, length: 4
# ----------------------
# |   F                |
# |      XX            |
# |   S  XX            |
# |   #                |
# |   # XX             |
# |   # XX             |
# |                    |
# |               XX   |
# |               XX   |
# |                    |
# |                    |
# ...
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-87.30000000000004  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |           XX       |
# |           XX       |
# |      F             |
# |                    |
# |      S             |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-58.200000000000024  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |           XX       |
# |           XX       |
# |      F             |
# |      S             |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-203.70000000000007  reward:10000, length: 2
# ----------------------
# |                    |
# |   F                |
# |           XX       |
# |           XX       |
# |      S             |
# |      #             |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-174.60000000000008  reward:0, length: 2
# ----------------------
# |                    |
# |   F                |
# |           XX       |
# |      S    XX       |
# |      #             |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-145.50000000000006  reward:0, length: 2
# ----------------------
# |                    |
# |   F                |
# |      S    XX       |
# |      #    XX       |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-116.40000000000005  reward:0, length: 2
# ----------------------
# |                    |
# |   F                |
# |     S#    XX       |
# |           XX       |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-87.30000000000004  reward:0, length: 2
# ----------------------
# |                    |
# |   F                |
# |    S#     XX       |
# |           XX       |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-58.200000000000024  reward:0, length: 2
# ----------------------
# |                    |
# |   F                |
# |   S#      XX       |
# |           XX       |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |                    |
# ----------------------
# features:[ 0  1  0  0 28]  statevalue:-816.1000000000003  reward:10000, length: 3
# ----------------------
# |                    |
# |   S                |
# |   ##      XX       |
# |           XX       |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |       XX           |
# |       XX           |
# |     XX             |
# |     XX             |
# |                    |
# |                    |
# |                  XX|
# |               F  XX|
# |                    |
# ----------------------
# features:[ 1  0  1  0 29]  statevalue:-847.2000000000003  reward:-1000, length: 3
# Game Over, Snake Length:3
# ----------------------
# |                    |
# |                    |
# |        F           |
# |                    |
# |                    |
# |                 XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 9]  statevalue:-288.0000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |        F           |
# |                    |
# |                    |
# |                 XX |
# |                 XX |
# |                    |
# |      S             |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 8]  statevalue:-256.0000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |        F           |
# |                    |
# |                    |
# |                 XX |
# |                 XX |
# |      S             |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 7]  statevalue:-224.0000000000001  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |        F           |
# |                    |
# |                    |
# |                 XX |
# |      S          XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 6]  statevalue:-192.00000000000009  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |        F           |
# |                    |
# |                    |
# |      S          XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-160.00000000000006  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |        F           |
# |                    |
# |      S             |
# |                 XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 4]  statevalue:-128.00000000000006  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |        F           |
# |      S             |
# |                    |
# |                 XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 3]  statevalue:-96.00000000000004  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |      S F           |
# |                    |
# |                    |
# |                 XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 2]  statevalue:-64.00000000000003  reward:0, length: 1
# ----------------------
# |                    |
# |                    |
# |       SF           |
# |                    |
# |                    |
# |                 XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 0 5]  statevalue:-160.00000000000006  reward:10000, length: 2
# ----------------------
# |    F               |
# |                    |
# |       #S           |
# |                    |
# |                    |
# |                 XX |
# |                 XX |
# |                    |
# |                    |
# |                    |
# |                    |
# |  XX                |
# |  XX                |
# |    XX              |
# |    XX              |
# |                    |
# |                    |
# |                    |
# |            XX      |
# |            XX      |
# ----------------------
# features:[0 0 0 1 6]  statevalue:-193.4000000000001  reward:-1000, length: 2
# Game Over, Snake Length:2
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 18]  statevalue:-586.8000000000003  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |             S      |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 17]  statevalue:-554.2000000000003  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |             S      |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 16]  statevalue:-521.6000000000003  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |                    |
# |                    |
# |                XX  |
# |             S  XX  |
# |                    |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 15]  statevalue:-489.0000000000002  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |                    |
# |                    |
# |             S  XX  |
# |                XX  |
# |                    |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 14]  statevalue:-456.4000000000002  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |                    |
# |             S      |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 13]  statevalue:-423.8000000000002  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |                    |
# |             S      |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 0  0  0  0 12]  statevalue:-391.20000000000016  reward:0, length: 1
# ----------------------
# |             F      |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                    |
# |                  XX|
# |                  XX|
# |        XX  XX      |
# |        XX  XX      |
# |             S      |
# |                    |
# |                    |
# |                XX  |
# |                XX  |
# |                    |
# |                    |
# |                    |
# |                    |
# ----------------------
# features:[ 1  0  0  0 11]  statevalue:-360.6000000000002  reward:-1000, length: 1
# Game Over, Snake Length:1

# %%
print(f"Training concluded after {iterations} iterations")
print(f"Longest snake length achieved: {longest_snake}")
print(f"Learned Weigths: {weights}")
# Out:
# Training concluded after 30 iterations
# Longest snake length achieved: 5
# Learned Weigths: [ -2.1  -1.3  -1.5  -1.5 -33.7]
